# %% [markdown]
# # Lung Segmentation
#
# Machine learning can help diagnose disease from medical images such as X-Rays and CT scans. One example of this is diagnosing pneumonia or pneumothorax from chest scans.
#
# Now such tasks might be easier if we know exactly where the lung is in the image! That's where **lung segmentation** comes into play.
#
# In this notebook we'll explore a new application of neural networks called **segmentation**. Segmentation is the task of identifying regions of interest in an image. We'll:
#
#
#
# *   Understand a dataset of *images* and *masks*
# *   Try a relatively simple CNN model, and understand why it fails
# *   Explore a different loss function, Dice, to improve our model
# *   (Optional) Try a special segmentation architecture, U-Nets
#
#
#
#  Let's check it out!

# %%
#@title Run to load data and helper functions
import matplotlib.pyplot as plt
import os
import numpy as np
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, concatenate, MaxPool2D, UpSampling2D
from sklearn.model_selection import train_test_split
import gdown
from ipywidgets import interact, IntSlider

IMG_PATH = "reduced/imgs"
MASK_PATH = "reduced/masks"
EPOCHS = 40

gdown.download("https://drive.google.com/uc?id=1_2UHVdkeuCHwwcb2RGs0cosNw8l_YoAE", "reduced.zip", True)
# !unzip -oq reduced.zip

np.random.seed(12)
tf.random.set_seed(12)

def load():
    imgs_paths = sorted([Path(IMG_PATH) / p for p in os.listdir(IMG_PATH)])
    masks_paths = sorted([Path(MASK_PATH) / p for p in os.listdir(MASK_PATH)])
    imgs = [plt.imread(p) for p in imgs_paths]
    masks = [plt.imread(p)[:, :, 0][:, :, None] > 0.5 for p in masks_paths]
    imgs, masks = np.array(imgs)[:,:,:,0:1], np.array(masks).astype(float)
    imgs_train, imgs_test, masks_train, masks_test = train_test_split(
        imgs, masks, test_size=0.2, shuffle=False
    )
    return imgs_train, imgs_test, masks_train, masks_test

def show_lung_mask_sbs(lung, mask):
    fig, (a1, a2) = plt.subplots(1, 2)
    a1.imshow(lung.squeeze(), cmap = 'gray')
    a2.imshow(mask.squeeze(), cmap = 'gray')
    a1.set_title("lung")
    a2.set_title("mask")


def show_lung_mask_pred_sbs(lung, mask, pred):
    fig, (a1, a2, a3) = plt.subplots(1, 3)
    a1.imshow(lung.squeeze(), cmap = 'gray')
    a2.imshow(mask.squeeze(), cmap = 'gray')
    a3.imshow(pred.squeeze(), cmap = 'gray')
    a1.set_title("lung")
    a2.set_title("mask")
    a3.set_title("predicted mask")

def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=(1, 2, 3))
    denominator = tf.reduce_sum(y_true + y_pred, axis=(1, 2, 3))
    return 1 - numerator / denominator

class ShowLearning(tf.keras.callbacks.Callback):
    def __init__(self, data, masks, name):
        self.data = data
        self.masks = masks
        self.fig_path = f"lung/figs/{name}"
        if not os.path.exists(self.fig_path):
            os.makedirs(self.fig_path)
        super().__init__()

    def on_epoch_begin(self, epoch, logs=None):
        rand_index = np.random.randint(0, len(self.data))
        rand_img = self.data[rand_index][None, :, :, :]
        mask = self.masks[rand_index][None, :, :, :]
        preds = self.model(rand_img).numpy() > 0.5
        show_lung_mask_pred_sbs(rand_img, mask, preds)
        plt.savefig(f"{self.fig_path}/epoch{epoch}.png")
        plt.close()

def show_training_image(name, epoch):
  im = plt.imread(f'lung/figs/{name}/epoch{epoch}.png')
  plt.imshow(im)

def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=(1, 2, 3))
    denominator = tf.reduce_sum(y_true + y_pred, axis=(1, 2, 3))
    return 1 - numerator / denominator

# %% [markdown]
# #Exploring our Data
#
# Let's start by loading in the data and checking out the shapes!
#
# We have lung images as well as their masks, which represent where in the image the lungs are located.

# %%
imgs_train, imgs_test, masks_train, masks_test = load()
print(imgs_train.shape, imgs_test.shape, masks_train.shape, masks_test.shape)
# Out:
# (213, 64, 64, 1) (54, 64, 64, 1) (213, 64, 64, 1) (54, 64, 64, 1)

# %% [markdown]
# **Discuss:** Can you explain the shape of each dataset?

# %% [markdown]
# ## Visualizing our data
#
# This is what the data looks like:

# %%
img_num = 20
show_lung_mask_sbs(imgs_train[img_num], masks_train[img_num])

# %% [markdown]
# **Question**: What are we trying to get our model trying to predict here? What are the inputs and outputs of the model?

# %% [markdown]
# **Exercise:** Use the code above and a for loop to look through the first 5 images.

# %%
for img_num in range(5):
  show_lung_mask_sbs(imgs_train[img_num], masks_train[img_num])

# %% [markdown]
# # Convolutional Neural Networks
#
# We'll start off with a simple convolutional neural network which is typically great for image processing, and see how it does. Note that this is the same as convolutional neural networks we have seen previously but instead of having one output which is the classification, it does a **binary classification on each pixel!**
#
# In particular, for each pixel, the model will have a prediction of whether or not that pixel is part of the lung.
#
# ## Exercise
#
# Add several Conv2D layers to the Sequential Model. To do this just add several calls to
#
# `Conv2D(filters = num_filters, kernel_size = kernel_size, strides = 1, padding='same', activation='relu')`
#
# For the num_filters parameter try any combination of 16 and 32, and for the kernel_size parameter use 3!
#
# We use a stride of `1` and padding of `same` to keep the output's height and width the same after each layer.
#
# **Question:** Why does the final layer have just 1 filter?

# %%
def SimpleConvModel():
    model = tf.keras.models.Sequential(
        [
            #### YOUR CODE HERE to add layers #########
            Conv2D(filters = 16, kernel_size = 3, strides = 1, padding='same', activation='relu'),
            Conv2D(filters = 32, kernel_size = 3, strides = 1, padding='same', activation='relu'),
            Conv2D(filters = 16, kernel_size = 3, strides = 1, padding='same', activation='relu'),
            ##### END CODE ########
            Conv2D(filters = 1, kernel_size = 3, strides = 1, padding="same", activation="sigmoid"),
        ]
    ) 
    return model

model = SimpleConvModel()

# %% [markdown]
# Run the next cell to train the model for 40 epochs. While it trains, follow the values of the loss and the accuracy.

# %%
def train(model, imgs, masks, loss, name, epochs):
    optimizer = tf.optimizers.Adam(learning_rate=0.0003)
    model.compile(optimizer=optimizer, loss=loss, metrics=["accuracy"])
    model.fit(imgs, masks, epochs=epochs, callbacks=[ShowLearning(imgs, masks, name)],)
    
train(model, imgs_train, masks_train, tf.losses.BinaryCrossentropy(), 'simple_conv', EPOCHS)
# Out:
# Epoch 1/40
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4126 - accuracy: 0.8117WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0054s vs `on_train_batch_end` time: 0.0055s). Check your callbacks.
# 7/7 [==============================] - 1s 11ms/step - loss: 0.4122 - accuracy: 0.8112
# Epoch 2/40
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4117 - accuracy: 0.8115
# Epoch 3/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4110 - accuracy: 0.8111
# Epoch 4/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4106 - accuracy: 0.8122
# Epoch 5/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4097 - accuracy: 0.8118
# Epoch 6/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4093 - accuracy: 0.8124
# Epoch 7/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4087 - accuracy: 0.8121
# Epoch 8/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4084 - accuracy: 0.8118
# Epoch 9/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4079 - accuracy: 0.8129
# Epoch 10/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4074 - accuracy: 0.8118
# Epoch 11/40
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4073 - accuracy: 0.8136
# Epoch 12/40
# 7/7 [==============================] - 1s 10ms/step - loss: 0.4066 - accuracy: 0.8120
# Epoch 13/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4058 - accuracy: 0.8134
# Epoch 14/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4055 - accuracy: 0.8121
# Epoch 15/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4050 - accuracy: 0.8136
# Epoch 16/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4044 - accuracy: 0.8132
# Epoch 17/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4040 - accuracy: 0.8137
# Epoch 18/40
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4039 - accuracy: 0.8128
# Epoch 19/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4037 - accuracy: 0.8141
# Epoch 20/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4025 - accuracy: 0.8137
# Epoch 21/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4022 - accuracy: 0.8143
# Epoch 22/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4018 - accuracy: 0.8142
# Epoch 23/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4013 - accuracy: 0.8137
# Epoch 24/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4012 - accuracy: 0.8142
# Epoch 25/40
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4005 - accuracy: 0.8145
# Epoch 26/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4001 - accuracy: 0.8144
# Epoch 27/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3996 - accuracy: 0.8145
# Epoch 28/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3993 - accuracy: 0.8147
# Epoch 29/40
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3997 - accuracy: 0.8138
# Epoch 30/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3989 - accuracy: 0.8151
# Epoch 31/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3979 - accuracy: 0.8148
# Epoch 32/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3977 - accuracy: 0.8155
# Epoch 33/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3978 - accuracy: 0.8152
# Epoch 34/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3971 - accuracy: 0.8150
# Epoch 35/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3965 - accuracy: 0.8149
# Epoch 36/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3965 - accuracy: 0.8158
# Epoch 37/40
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3961 - accuracy: 0.8152
# Epoch 38/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3956 - accuracy: 0.8159
# Epoch 39/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3959 - accuracy: 0.8145
# Epoch 40/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3962 - accuracy: 0.8158

# %% [markdown]
# ### Predicting Model Output Size
# **Discuss: What should the output size of our model be? Why?**
#
# Check your prediction below! We can also visualize the structure of our model.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        320
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 16)        4624
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 1)         145
# =================================================================
# Total params: 5,089
# Trainable params: 5,089
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Our model probably achieved **> 80% accuracy** - not bad!!
#
# Or is it? Let's take a look at some of the predictions. You'll see that our model got better over time - but how much better?

# %%
interact(lambda epoch: show_training_image('simple_conv', epoch), epoch=(0, EPOCHS-1));
# Out:
# interactive(children=(IntSlider(value=19, description='epoch', max=39), Output()), _dom_classes=('widget-inter…

# %% [markdown]
# **Question:** Why is the accuracy so high when the results look so unimpressive? How exactly is accuracy calculated?

# %% [markdown]
# ## Understanding Model Accuracy
# **Exercise:** In the masks, what is the percentage of pixels that are part of the lung?
#
# *Hint:* The pixels that are part of the lung are represented as `1` in `masks_train`, so you can find the total number of lung pixels with  `masks_train.sum()`.
#
# You might also find `masks_train.size` useful!

# %%
print(masks_train.sum()/masks_train.size)
# Out:
# 0.23375605193661972

# %% [markdown]
# **Question:** What accuracy could we get if we just predicted all the pixels were not part of the lung?
#
# **Question:** Why is accuracy not super useful for this segmentation task?

# %% [markdown]
# Well, it seems like the model is outputing 'not lung' for most pixels. And because in our images most of the pixels are not part of the lung, the model can get pretty high accuracy by just guessing 'not lung' for each pixel! This is clearly not what we want.
#
# We can try something to address this. First of all, we'll need to rethink what it means to have a 'good' prediction, as just accuracy is clearly not adequate! We need some way to measure how much overlap there is between the *real* lung masks and our predictions.

# %% [markdown]
# #Exploring the Loss Function
#
# ##The Dice Coefficient
#
# Instead of accuracy, we'll use a common metric known as the Dice Coefficient (or Sørensen–Dice if you're feeling fancy), which is calculated as follows:
#
# $$\frac{2*|T \cap P|}{|T| + |P|}$$
#
# ![test](https://miro.medium.com/max/429/1*yUd5ckecHjWZf6hGrdlwzA.png)
#
# **$T$**, in blue, is the set of pixels in the image that are **truly part of the lung.**
#
# **$P$**, in red, is the set of pixels that are **predicted to be part of the lung**.
#
# The numerator is the **overlap of true and predicted**: how many pixels are in both categories?
#
# The denominator is the **sum** of **the number of pixels truly in the lung**, plus **the number of pixels that are predicted to be part of the lung**.
#
# Some intuition: to get a high (good) Dice Coefficient, we need a **large numerator** and a **small denominator**.
# * To make the numerator large, there needs to be a lot of overlap between the true and predicted 'lung' pixels.
# * To make the denominator small, there shouldn't be that many pixels that are predicted as 'lung' - otherwise we could "cheat" by predicting everything is part of the lung!
#
# **Question:** What would the Dice Coefficient be if we make a perfect prediction? Why is there a 2 in the numerator?
#
# **Question:** What would the Dice Coefficient be if we predict all 'not lung'?
#
# **Question**: What's another way we could get a Dice Coefficient of 0?

# %% [markdown]
# ## (Optional, Advanced): Implementing Dice
# **Exercise:** Implement a function that returns the Dice coefficient.
#
# Hint:  `sum(true_mask & predicted_mask`) counts the number of pixels that are in both the true mask and the predicted mask.

# %%
def dice(true_mask, predicted_mask):
    #flatten the data
    true_mask, predicted_mask = true_mask.astype(bool).flatten(), predicted_mask.astype(bool).flatten()
    
    #YOUR CODE HERE to return the dice coefficient

# %% [markdown]
# Now, let's try out our Dice score - how well do our predictions do? By changing the inputs, can you achieve a Dice score of 0.0 or 1.0?

# %%
img_num = 43 #Choose any image

img = np.expand_dims(imgs_train[img_num],0)
true_mask = masks_train[img_num]
pred_mask = model.predict(img) > 0.5

show_lung_mask_pred_sbs(img, true_mask, pred_mask)

print("Dice score:", dice(true_mask, pred_mask)) #Try changing the inputs to dice!

# %%
#YOUR CODE HERE to explore changing the inputs (create some arrays!)

# %% [markdown]
# ## Same model, different loss
#
# To make our model actually *find* the lungs rather than using the "always guess no" trick, we can try changing the loss function. Remember that the **the model tries to minimize the loss function during training**. Now that we care about the Dice Coefficient more than accuracy, we can change our loss function to reflect that.
#
# Note that "Dice Loss" is just 1 - Dice: minimizing Dice Loss is the same thing as maximizing the Dice Coefficient!

# %%
for i in range(5):
  model_with_dice = SimpleConvModel()
  train(model_with_dice, imgs_train, masks_train, dice_loss, 'simple_conv_with_dice', EPOCHS)
# Out:
# Epoch 1/40
# 7/7 [==============================] - 1s 10ms/step - loss: 0.6862 - accuracy: 0.5199
# Epoch 2/40
# 7/7 [==============================] - 1s 10ms/step - loss: 0.6849 - accuracy: 0.4244
# Epoch 3/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6833 - accuracy: 0.3735
# Epoch 4/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6813 - accuracy: 0.3342
# Epoch 5/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6787 - accuracy: 0.3081
# Epoch 6/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6753 - accuracy: 0.2931
# Epoch 7/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6710 - accuracy: 0.2841
# Epoch 8/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6656 - accuracy: 0.2790
# Epoch 9/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6593 - accuracy: 0.2782
# Epoch 10/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6519 - accuracy: 0.2803
# Epoch 11/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6439 - accuracy: 0.2872
# Epoch 12/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6353 - accuracy: 0.2991
# Epoch 13/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6264 - accuracy: 0.3158
# Epoch 14/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6178 - accuracy: 0.3361
# Epoch 15/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6097 - accuracy: 0.3588
# Epoch 16/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6024 - accuracy: 0.3803
# Epoch 17/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5960 - accuracy: 0.3993
# Epoch 18/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5903 - accuracy: 0.4146
# Epoch 19/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5856 - accuracy: 0.4273
# Epoch 20/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5815 - accuracy: 0.4372
# Epoch 21/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5780 - accuracy: 0.4445
# Epoch 22/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5752 - accuracy: 0.4512
# Epoch 23/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5727 - accuracy: 0.4562
# Epoch 24/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5706 - accuracy: 0.4595
# Epoch 25/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5688 - accuracy: 0.4630
# Epoch 26/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5672 - accuracy: 0.4667
# Epoch 27/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5657 - accuracy: 0.4695
# Epoch 28/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5644 - accuracy: 0.4717
# Epoch 29/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5632 - accuracy: 0.4734
# Epoch 30/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5620 - accuracy: 0.4758
# Epoch 31/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5610 - accuracy: 0.4787
# Epoch 32/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5600 - accuracy: 0.4822
# Epoch 33/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5589 - accuracy: 0.4844
# Epoch 34/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5580 - accuracy: 0.4850
# Epoch 35/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5570 - accuracy: 0.4866
# Epoch 36/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5561 - accuracy: 0.4884
# Epoch 37/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5552 - accuracy: 0.4908
# Epoch 38/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5543 - accuracy: 0.4942
# Epoch 39/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5534 - accuracy: 0.4957
# Epoch 40/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5525 - accuracy: 0.4965
# Epoch 1/40
# 7/7 [==============================] - 1s 11ms/step - loss: 0.6865 - accuracy: 0.5839
# Epoch 2/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6855 - accuracy: 0.5321
# Epoch 3/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6845 - accuracy: 0.5206
# Epoch 4/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6833 - accuracy: 0.5116
# Epoch 5/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6818 - accuracy: 0.5024
# Epoch 6/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6798 - accuracy: 0.4946
# Epoch 7/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6773 - accuracy: 0.4875
# Epoch 8/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6740 - accuracy: 0.4822
# Epoch 9/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6700 - accuracy: 0.4776
# Epoch 10/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6649 - accuracy: 0.4726
# Epoch 11/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6590 - accuracy: 0.4687
# Epoch 12/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6520 - accuracy: 0.4649
# Epoch 13/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6438 - accuracy: 0.4598
# Epoch 14/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6350 - accuracy: 0.4565
# Epoch 15/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6256 - accuracy: 0.4534
# Epoch 16/40
# 7/7 [==============================] - 1s 9ms/step - loss: 0.6164 - accuracy: 0.4517
# Epoch 17/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6075 - accuracy: 0.4513
# Epoch 18/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5994 - accuracy: 0.4517
# Epoch 19/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5926 - accuracy: 0.4545
# Epoch 20/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5867 - accuracy: 0.4567
# Epoch 21/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5820 - accuracy: 0.4581
# Epoch 22/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5782 - accuracy: 0.4612
# Epoch 23/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5750 - accuracy: 0.4636
# Epoch 24/40
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5725 - accuracy: 0.4647
# Epoch 25/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5704 - accuracy: 0.4670
# Epoch 26/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5686 - accuracy: 0.4700
# Epoch 27/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5671 - accuracy: 0.4718
# Epoch 28/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5657 - accuracy: 0.4726
# Epoch 29/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5644 - accuracy: 0.4736
# Epoch 30/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5633 - accuracy: 0.4757
# Epoch 31/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5622 - accuracy: 0.4778
# Epoch 32/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5613 - accuracy: 0.4807
# Epoch 33/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5603 - accuracy: 0.4817
# Epoch 34/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5594 - accuracy: 0.4821
# Epoch 35/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5585 - accuracy: 0.4844
# Epoch 36/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5576 - accuracy: 0.4853
# Epoch 37/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5568 - accuracy: 0.4864
# Epoch 38/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5560 - accuracy: 0.4898
# Epoch 39/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5551 - accuracy: 0.4911
# Epoch 40/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5543 - accuracy: 0.4916
# Epoch 1/40
# 7/7 [==============================] - 1s 11ms/step - loss: 0.6856 - accuracy: 0.5740
# Epoch 2/40
# 7/7 [==============================] - 1s 12ms/step - loss: 0.6842 - accuracy: 0.5182
# Epoch 3/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6826 - accuracy: 0.5028
# Epoch 4/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6804 - accuracy: 0.4906
# Epoch 5/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6778 - accuracy: 0.4802
# Epoch 6/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6745 - accuracy: 0.4696
# Epoch 7/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6704 - accuracy: 0.4577
# Epoch 8/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6651 - accuracy: 0.4460
# Epoch 9/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6586 - accuracy: 0.4363
# Epoch 10/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6506 - accuracy: 0.4275
# Epoch 11/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6415 - accuracy: 0.4222
# Epoch 12/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6315 - accuracy: 0.4195
# Epoch 13/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6212 - accuracy: 0.4169
# Epoch 14/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6113 - accuracy: 0.4182
# Epoch 15/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6024 - accuracy: 0.4220
# Epoch 16/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5949 - accuracy: 0.4273
# Epoch 17/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5888 - accuracy: 0.4333
# Epoch 18/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5839 - accuracy: 0.4382
# Epoch 19/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5802 - accuracy: 0.4433
# Epoch 20/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5772 - accuracy: 0.4475
# Epoch 21/40
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5749 - accuracy: 0.4504
# Epoch 22/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5729 - accuracy: 0.4540
# Epoch 23/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5712 - accuracy: 0.4568
# Epoch 24/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5697 - accuracy: 0.4584
# Epoch 25/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5684 - accuracy: 0.4608
# Epoch 26/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5671 - accuracy: 0.4639
# Epoch 27/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5660 - accuracy: 0.4662
# Epoch 28/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5649 - accuracy: 0.4680
# Epoch 29/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5639 - accuracy: 0.4694
# Epoch 30/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5629 - accuracy: 0.4716
# Epoch 31/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5619 - accuracy: 0.4742
# Epoch 32/40
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5610 - accuracy: 0.4773
# Epoch 33/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5600 - accuracy: 0.4793
# Epoch 34/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5591 - accuracy: 0.4800
# Epoch 35/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5582 - accuracy: 0.4820
# Epoch 36/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5573 - accuracy: 0.4836
# Epoch 37/40
# 7/7 [==============================] - 1s 11ms/step - loss: 0.5564 - accuracy: 0.4856
# Epoch 38/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5555 - accuracy: 0.4891
# Epoch 39/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5546 - accuracy: 0.4909
# Epoch 40/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5536 - accuracy: 0.4920
# Epoch 1/40
# 7/7 [==============================] - 1s 11ms/step - loss: 0.6854 - accuracy: 0.6027
# Epoch 2/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6840 - accuracy: 0.5547
# Epoch 3/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6824 - accuracy: 0.5440
# Epoch 4/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6805 - accuracy: 0.5358
# Epoch 5/40
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6782 - accuracy: 0.5273
# Epoch 6/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6754 - accuracy: 0.5190
# Epoch 7/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6720 - accuracy: 0.5105
# Epoch 8/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6678 - accuracy: 0.5027
# Epoch 9/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6628 - accuracy: 0.4952
# Epoch 10/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6569 - accuracy: 0.4879
# Epoch 11/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6504 - accuracy: 0.4813
# Epoch 12/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6430 - accuracy: 0.4749
# Epoch 13/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6350 - accuracy: 0.4671
# Epoch 14/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6266 - accuracy: 0.4620
# Epoch 15/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6179 - accuracy: 0.4599
# Epoch 16/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6096 - accuracy: 0.4595
# Epoch 17/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6019 - accuracy: 0.4590
# Epoch 18/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5950 - accuracy: 0.4585
# Epoch 19/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5892 - accuracy: 0.4606
# Epoch 20/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5843 - accuracy: 0.4618
# Epoch 21/40
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5802 - accuracy: 0.4620
# Epoch 22/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5770 - accuracy: 0.4640
# Epoch 23/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5743 - accuracy: 0.4651
# Epoch 24/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5721 - accuracy: 0.4654
# Epoch 25/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5703 - accuracy: 0.4673
# Epoch 26/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5687 - accuracy: 0.4694
# Epoch 27/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5673 - accuracy: 0.4708
# Epoch 28/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5660 - accuracy: 0.4721
# Epoch 29/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5648 - accuracy: 0.4732
# Epoch 30/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5637 - accuracy: 0.4748
# Epoch 31/40
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5626 - accuracy: 0.4769
# Epoch 32/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5616 - accuracy: 0.4799
# Epoch 33/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5606 - accuracy: 0.4814
# Epoch 34/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5597 - accuracy: 0.4821
# Epoch 35/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5587 - accuracy: 0.4844
# Epoch 36/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5577 - accuracy: 0.4856
# Epoch 37/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5568 - accuracy: 0.4872
# Epoch 38/40
# 7/7 [==============================] - 1s 12ms/step - loss: 0.5559 - accuracy: 0.4909
# Epoch 39/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5549 - accuracy: 0.4925
# Epoch 40/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5539 - accuracy: 0.4934
# Epoch 1/40
# 7/7 [==============================] - 1s 10ms/step - loss: 0.6856 - accuracy: 0.2752
# Epoch 2/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6841 - accuracy: 0.2473
# Epoch 3/40
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6822 - accuracy: 0.2509
# Epoch 4/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6798 - accuracy: 0.2544
# Epoch 5/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6765 - accuracy: 0.2562
# Epoch 6/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6723 - accuracy: 0.2564
# Epoch 7/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6668 - accuracy: 0.2559
# Epoch 8/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6599 - accuracy: 0.2567
# Epoch 9/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6519 - accuracy: 0.2599
# Epoch 10/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6428 - accuracy: 0.2667
# Epoch 11/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6335 - accuracy: 0.2779
# Epoch 12/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6242 - accuracy: 0.2942
# Epoch 13/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6154 - accuracy: 0.3166
# Epoch 14/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6075 - accuracy: 0.3417
# Epoch 15/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6003 - accuracy: 0.3677
# Epoch 16/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5940 - accuracy: 0.3909
# Epoch 17/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5883 - accuracy: 0.4111
# Epoch 18/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5833 - accuracy: 0.4268
# Epoch 19/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5792 - accuracy: 0.4395
# Epoch 20/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5756 - accuracy: 0.4483
# Epoch 21/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5727 - accuracy: 0.4549
# Epoch 22/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5702 - accuracy: 0.4599
# Epoch 23/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5680 - accuracy: 0.4636
# Epoch 24/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5662 - accuracy: 0.4660
# Epoch 25/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5646 - accuracy: 0.4688
# Epoch 26/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5631 - accuracy: 0.4718
# Epoch 27/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5618 - accuracy: 0.4743
# Epoch 28/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5606 - accuracy: 0.4762
# Epoch 29/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5595 - accuracy: 0.4779
# Epoch 30/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5584 - accuracy: 0.4803
# Epoch 31/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5573 - accuracy: 0.4830
# Epoch 32/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5564 - accuracy: 0.4866
# Epoch 33/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5553 - accuracy: 0.4890
# Epoch 34/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5543 - accuracy: 0.4895
# Epoch 35/40
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5534 - accuracy: 0.4912
# Epoch 36/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5524 - accuracy: 0.4932
# Epoch 37/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5514 - accuracy: 0.4958
# Epoch 38/40
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5505 - accuracy: 0.4997
# Epoch 39/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5495 - accuracy: 0.5016
# Epoch 40/40
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5484 - accuracy: 0.5025

# %%
interact(lambda epoch: show_training_image('simple_conv_with_dice', epoch), epoch=(0, EPOCHS-1));
# Out:
# interactive(children=(IntSlider(value=19, description='epoch', max=39), Output()), _dom_classes=('widget-inter…

# %% [markdown]
# **Question**: Compare the above results to the results from before. Are the predictions any better or more believable than before? What is a new problem that is arising?

# %% [markdown]
# # (Optional) Changing Our Model: U-Nets
#
# So even though we have changed our loss to better suit the problem, we can still do better! To do this, we'll use U-Nets, which are a special type of convolutional neural network with a "U shaped" architecture. It works by first compressing and then expanding the image back to full size.
#
# Compressing the image (on the left side of the U) allows us to create many feature maps. Then - since for segmentation we need to output an image of the same size as the original - we upsample. Importantly, we also copy the original feature maps of a particular size during the compression stage. This greatly reduces distortion, as it is like we have a copy of the original image in the expansion section.
#
# U-Nets are tricky to understand - no worries if you're fuzzy on some of the details!
# ![alt text](https://miro.medium.com/max/2824/1*f7YOaE4TWubwaFF7Z1fzNw.png)

# %% [markdown]
# We've implemented a small U-Net for you here (**not exactly the diagram**). Check it out and experiment with it if you're interested! You'll notice it has only five "sections" total (two on the way down, one at the bottom, and two on the way up). What does each section consist of?
#
# **Try drawing a diagram for this U-Net!**

# %%
#Check out the U-Net code if you're interested!

def section(conv1_filters, conv2_filters): #Represents one horizontal "section" of the U
    return tf.keras.Sequential(
        [
            Conv2D(conv1_filters, 3, padding="same", activation="relu"),
            Conv2D(conv2_filters, 3, padding="same", activation="relu"),
        ]
    )

class U_Net(tf.keras.Model):
    def __init__(self):
        super(U_Net, self).__init__() #What do the numbers represent? 
        self.section1 = section(16, 16)
        self.section2 = section(32, 32)
        self.section3 = section(32, 64) #Bottom of the U!
        self.section4 = section(32, 32)
        self.section5 = section(16, 16)
        self.final_conv = Conv2D(1, 3, padding="same", activation="sigmoid")
        self.maxpool1, self.maxpool2 = MaxPool2D(2), MaxPool2D(2) #Why are there two of these?
        self.upsample1, self.upsample2 = UpSampling2D(2), UpSampling2D(2)

    def call(self, inputs):
        input1 = self.section1(inputs)
        input2 = self.section2(self.maxpool1(input1))
        input3 = self.section3(self.maxpool2(input2))
        input4 = self.section4(concatenate([input2, self.upsample1(input3)]))
        input5 = self.section5(concatenate([input1, self.upsample2(input4)]))
        output = self.final_conv(input5)
        return output

# %%
unet = U_Net()

# %% [markdown]
# Let's use Dice Loss with our U-Net.
#
# As this model trains, look at how the accuracy and loss change. Is the training generally steady or are there certain epochs with breakthroughs?

# %%
train(unet, imgs_train, masks_train, dice_loss, 'unet_with_dice', epochs=EPOCHS)
# Out:
# Epoch 1/40
# 7/7 [==============================] - 2s 81ms/step - loss: 0.6861 - accuracy: 0.3198
# Epoch 2/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6820 - accuracy: 0.2340
# Epoch 3/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.6602 - accuracy: 0.2338
# Epoch 4/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6100 - accuracy: 0.2339
# Epoch 5/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.6045 - accuracy: 0.2343
# Epoch 6/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.5927 - accuracy: 0.2729
# Epoch 7/40
# 7/7 [==============================] - 0s 19ms/step - loss: 0.5738 - accuracy: 0.3603
# Epoch 8/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.5102 - accuracy: 0.6186
# Epoch 9/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.3676 - accuracy: 0.8288
# Epoch 10/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.3237 - accuracy: 0.8405
# Epoch 11/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2983 - accuracy: 0.8403
# Epoch 12/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.2671 - accuracy: 0.8585
# Epoch 13/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.2344 - accuracy: 0.8878
# Epoch 14/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2177 - accuracy: 0.9021
# Epoch 15/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.2034 - accuracy: 0.9099
# Epoch 16/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1989 - accuracy: 0.9116
# Epoch 17/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1958 - accuracy: 0.9123
# Epoch 18/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1889 - accuracy: 0.9155
# Epoch 19/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1846 - accuracy: 0.9176
# Epoch 20/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1830 - accuracy: 0.9171
# Epoch 21/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1788 - accuracy: 0.9195
# Epoch 22/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1757 - accuracy: 0.9214
# Epoch 23/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1713 - accuracy: 0.9230
# Epoch 24/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1688 - accuracy: 0.9240
# Epoch 25/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1682 - accuracy: 0.9250
# Epoch 26/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1654 - accuracy: 0.9257
# Epoch 27/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1603 - accuracy: 0.9282
# Epoch 28/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1578 - accuracy: 0.9291
# Epoch 29/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1539 - accuracy: 0.9318
# Epoch 30/40
# 7/7 [==============================] - 1s 17ms/step - loss: 0.1470 - accuracy: 0.9335
# Epoch 31/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1451 - accuracy: 0.9359
# Epoch 32/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1373 - accuracy: 0.9384
# Epoch 33/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1341 - accuracy: 0.9412
# Epoch 34/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1325 - accuracy: 0.9407
# Epoch 35/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1351 - accuracy: 0.9409
# Epoch 36/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1317 - accuracy: 0.9424
# Epoch 37/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1291 - accuracy: 0.9425
# Epoch 38/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1174 - accuracy: 0.9483
# Epoch 39/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1127 - accuracy: 0.9504
# Epoch 40/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1111 - accuracy: 0.9517

# %%
interact(lambda epoch: show_training_image('unet_with_dice', epoch), epoch=(0, EPOCHS-1));
# Out:
# interactive(children=(IntSlider(value=19, description='epoch', max=39), Output()), _dom_classes=('widget-inter…

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Run the next cell to visualize the predictions of the UNet on the test set! As a reminder, our model has never seen this data before. Will it be able to predict somewhat accurate looking masks?

# %%
thresh = 0.5 #Experiment with changing this!
preds = unet(imgs_test).numpy()
preds = preds >= thresh

def show_preds_helper(imgs_test, masks_test, preds, ind):
    show_lung_mask_pred_sbs(imgs_test[ind], masks_test[ind], preds[ind])
    plt.show()

interact(lambda i: show_preds_helper(imgs_test, masks_test, preds, i), i=(0, len(preds)-1));
# Out:
# interactive(children=(IntSlider(value=26, description='i', max=53), Output()), _dom_classes=('widget-interact'…

# %% [markdown]
# Pretty darn good :)

# %% [markdown]
# ## Advanced: Improving Your Model
#
# Keep experimenting with our models to see if you can achieve human-level performance! You can try a few things:
#
#
# *   Train for more epochs.
# *   Try changing the hyperparameters, like learning rate.
# *   Experiment with the structure of U-Net: can you change the number of sections, or the sizes of the convolutions within each section?
# *   Change the threshold for our prediction. For example, if we see that we're overpredicting lung pixels, we could set our threshold a little higher. Remember that the raw output of our models is a probability value for each pixel on whether or not it is part of the lung!
# *   *Advanced Challenge*: try implementing a different loss function, like the [Jaccard index](https://en.wikipedia.org/wiki/Jaccard_index) or [pixel-wise cross-entropy loss](https://www.jeremyjordan.me/semantic-segmentation/) (which is the loss function we used in our first model). Check out the `dice_loss` function in the hidden cell at the top for an example of the function's structure.
#
# Work with your group to see if you can create a perfect model!

# %%
train(unet, imgs_train, masks_train, dice_loss, 'unet_with_dice', epochs=70)
# Out:
# Epoch 1/70
# 5/7 [====================>.........] - ETA: 0s - loss: 0.1440 - accuracy: 0.9309WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0113s vs `on_train_batch_end` time: 0.0177s). Check your callbacks.
# 7/7 [==============================] - 2s 29ms/step - loss: 0.1292 - accuracy: 0.9395
# Epoch 2/70
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0973 - accuracy: 0.9568
# Epoch 3/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0821 - accuracy: 0.9648
# Epoch 4/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0780 - accuracy: 0.9669
# Epoch 5/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0752 - accuracy: 0.9677
# Epoch 6/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0730 - accuracy: 0.9690
# Epoch 7/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0710 - accuracy: 0.9699
# Epoch 8/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0698 - accuracy: 0.9702
# Epoch 9/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0689 - accuracy: 0.9706
# Epoch 10/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0685 - accuracy: 0.9707
# Epoch 11/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0679 - accuracy: 0.9709
# Epoch 12/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0681 - accuracy: 0.9708
# Epoch 13/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0673 - accuracy: 0.9711
# Epoch 14/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0664 - accuracy: 0.9716
# Epoch 15/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0661 - accuracy: 0.9717
# Epoch 16/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0659 - accuracy: 0.9716
# Epoch 17/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0657 - accuracy: 0.9718
# Epoch 18/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0654 - accuracy: 0.9719
# Epoch 19/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0662 - accuracy: 0.9715
# Epoch 20/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0650 - accuracy: 0.9720
# Epoch 21/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0643 - accuracy: 0.9725
# Epoch 22/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0636 - accuracy: 0.9727
# Epoch 23/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0653 - accuracy: 0.9717
# Epoch 24/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0646 - accuracy: 0.9721
# Epoch 25/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0637 - accuracy: 0.9727
# Epoch 26/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0624 - accuracy: 0.9731
# Epoch 27/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0616 - accuracy: 0.9735
# Epoch 28/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0613 - accuracy: 0.9734
# Epoch 29/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0615 - accuracy: 0.9734
# Epoch 30/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0607 - accuracy: 0.9737
# Epoch 31/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0622 - accuracy: 0.9731
# Epoch 32/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0619 - accuracy: 0.9732
# Epoch 33/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0624 - accuracy: 0.9731
# Epoch 34/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0612 - accuracy: 0.9735
# Epoch 35/70
# 7/7 [==============================] - 1s 17ms/step - loss: 0.0594 - accuracy: 0.9743
# Epoch 36/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0593 - accuracy: 0.9744
# Epoch 37/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0589 - accuracy: 0.9744
# Epoch 38/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0589 - accuracy: 0.9745
# Epoch 39/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0590 - accuracy: 0.9742
# Epoch 40/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0587 - accuracy: 0.9745
# Epoch 41/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0585 - accuracy: 0.9747
# Epoch 42/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0595 - accuracy: 0.9739
# Epoch 43/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0585 - accuracy: 0.9746
# Epoch 44/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0583 - accuracy: 0.9746
# Epoch 45/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0572 - accuracy: 0.9751
# Epoch 46/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0572 - accuracy: 0.9752
# Epoch 47/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0563 - accuracy: 0.9755
# Epoch 48/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0561 - accuracy: 0.9756
# Epoch 49/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0557 - accuracy: 0.9759
# Epoch 50/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0565 - accuracy: 0.9754
# Epoch 51/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0559 - accuracy: 0.9756
# Epoch 52/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0563 - accuracy: 0.9755
# Epoch 53/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0554 - accuracy: 0.9758
# Epoch 54/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0553 - accuracy: 0.9759
# Epoch 55/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0571 - accuracy: 0.9750
# Epoch 56/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0553 - accuracy: 0.9759
# Epoch 57/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0545 - accuracy: 0.9763
# Epoch 58/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0542 - accuracy: 0.9763
# Epoch 59/70
# 7/7 [==============================] - 1s 17ms/step - loss: 0.0548 - accuracy: 0.9760
# Epoch 60/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0557 - accuracy: 0.9757
# Epoch 61/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0554 - accuracy: 0.9758
# Epoch 62/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0553 - accuracy: 0.9759
# Epoch 63/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0537 - accuracy: 0.9766
# Epoch 64/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0533 - accuracy: 0.9767
# Epoch 65/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0537 - accuracy: 0.9765
# Epoch 66/70
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0542 - accuracy: 0.9763
# Epoch 67/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0545 - accuracy: 0.9761
# Epoch 68/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0530 - accuracy: 0.9769
# Epoch 69/70
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0523 - accuracy: 0.9771
# Epoch 70/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0525 - accuracy: 0.9770

# %% [markdown]
# ## References and Acknowledgements:
# * Some of these exercises were inspired by CS271 at Stanford
# * [Data](https://www.kaggle.com/kmader/finding-lungs-in-ct-data/data?select=lung_stats.csv)
# * [Dice Loss](https://lars76.github.io/neural-networks/object-detection/losses-for-segmentation/)
# * [Tensorflow](https://www.tensorflow.org/api_docs/python/tf/keras)
#
# Original Notebook by Harry Sha
