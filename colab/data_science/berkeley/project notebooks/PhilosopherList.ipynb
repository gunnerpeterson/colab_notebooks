# %%
from tensorflow import keras

filepath = '/content/philosophers.txt'

with open(filepath, "r") as africa_text:
  africa = africa_text.read()

print(africa[:100000])

africa_start_index = 50000
africa_end_index = 1400000

Analects_start_index = 34000
Analects_end_index = 193000

Aquinas_start_index = 250
Aquinas_end_index = 58600
Aquinas_removal = ["Get any book for free on: www.Abika.com", "ON BEING AND ESSENCE"]

City_start_index = 10000
City_end_index = 2500000

Discourses_start_index = 35000
Discourses_end_index = 450000

Fire_start_index = 2000
Fire_end_index = 1000000

Gita_start_index = 9000
Gita_end_index = 305000

Hegel_start_index = 70000
Hegel_end_index = 2025200

Heidigger_start_index = 35000
Heidigger_end_index = 1120000

Investigations_start_index = 3000
Investigations_end_index = 1130000
Investigations_removal = ["§"]

Kant_start_index = 700000
Kant_end_index = 2000000

Locke_start_index = 5000
Locke_end_index = 9000000

Ludwig_start_index = 35000
Ludwig_end_index = 161500

Mary_start_index = 53000
Mary_end_index = 5300000

Meditations_start_index = 720
Meditations_end_index = 157500

Michel_start_index = 3500
Michel_end_index = 770000

Morality_start_index = 5000
Morality_end_index = 530000

Plato_start_index = 76700
Plato_end_index = 750000

Russell_start_index = 3000
Russell_end_index = 275000

Sage_start_index = 1
Sage_end_index = 10000000

Satre_start_index = 30000
Satre_end_index = 5000000

Second_start_index = 80000
Second_end_index = 2000000

Sisyphus_start_index = 2700
Sisyphus_end_index = 314000

Tao_start_index = 8000
Tao_end_index = 65000

Unapishads_start_index = 3000
Unapishads_end_index = 315000

Woolf_start_index = 1200
Woolf_end_index = 205000
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# 1.   Indian Philosophy
#     - The Unapishads
#     - The Bhagavad Gita
# 2.   Chinese Philosophy
#     - The Tao Te Ching
#     - The Analects of Confucius
# 3. Greek Philosophy
#     - Plato's Republic
#     - Discourses, Epictetus
# 4. Medieval Christian Philosophy
#     - The City of God, Augustine
#     - On Being and Essence, Aquinas
# 5. The Enlightenment
#   - Meditations on First Philosophy, Descartes
#   - Essay Concerning Human Understanding, Locke
# 6. German Idealism
#   - Critique of Pure Reason, Kant
#   - The Phenomenology of the Spirit, Hegel
# 7. Feminism
#   - A Room of One's Own, Woolf
#   - The Second Sex, de Beauvoir
#   - A Vindication of the Rights of Woman, Wollstonecraft
# 8. African Philosophy
#   - Sage Philosophy: Indigenous Thinkers and Modern Debate on African Philosophy, Odera
#   - A Companion to African Philosophy, TEXTBOOK
# 9. Phenomonology
#   - Logical Investigations, Husserl
#   - Being and Time, Heidegger
# 10. Existentialism
#   - Being and Nothingness, Sartre
#   - The Myth of Sisyphus, Camus
# 11. Modern Analytic Philosophy
#   - Tractatus Logico-Philosophicus, Wittgenstein
#   - The problems of Philosophy, Russell
# 12. Postmodernism
#   - On the Genealogy of Morality, Nietzsche
#   - Discipline and Punish, Foucault

# %%
filepath = '/content/African.txt'

with open(filepath) as f:
  African = f.read()
African = African[africa_start_index:africa_end_index]


filepath = '/content/Analects.txt'

with open(filepath) as f:
  Analects = f.read()
Analects = Analects[Analects_start_index:Analects_end_index]


filepath = '/content/Aquinas.txt'

with open(filepath) as f:
  Aquinas = f.read()
Aquinas = Aquinas[Aquinas_start_index:Aquinas_end_index]


filepath = '/content/City.txt'

with open(filepath) as f:
  City = f.read()
City = City[City_start_index:City_end_index]

filepath = '/content/Discourses.txt'

with open(filepath) as f:
  Discourses = f.read()
Discourses = Discourses[Discourses_start_index:Discourses_end_index]


filepath = '/content/Fire.txt'

with open(filepath) as f:
  Fire = f.read()
Fire = Fire[Fire_start_index:Fire_end_index]


filepath = '/content/Gita.txt'

with open(filepath) as f:
  Gita = f.read()
Gita = Gita[Gita_start_index:Gita_end_index]


filepath = '/content/Hegel.txt'

with open(filepath) as f:
  Hegel = f.read()
Hegel = Hegel[Hegel_start_index:Hegel_end_index]

filepath = '/content/Heidigger.txt'

with open(filepath) as f:
  Heidigger = f.read()
Heidigger = Heidigger[Heidigger_start_index:Heidigger_end_index]


filepath = '/content/Investigations.txt'

with open(filepath) as f:
  Investigations = f.read()
Investigations = Investigations[Investigations_start_index:Investigations_end_index]


filepath = '/content/Kant.txt'

with open(filepath) as f:
  Kant = f.read()
Kant = Kant[Kant_start_index:Kant_end_index]


filepath = '/content/Locke.txt'

with open(filepath) as f:
  Locke = f.read()
Locke = Locke[Locke_start_index:Locke_end_index]

filepath = '/content/Ludwig.txt'

with open(filepath) as f:
  Ludwig = f.read()
Ludwig = Ludwig[Ludwig_start_index:Ludwig_end_index]


filepath = '/content/Mary.txt'

with open(filepath) as f:
  Mary = f.read()
Mary = Mary[Mary_start_index:Mary_end_index]


filepath = '/content/Meditations.txt'

with open(filepath) as f:
  Meditations = f.read()
Meditations = Meditations[Meditations_start_index:Meditations_end_index]


filepath = '/content/Michel.txt'

with open(filepath) as f:
  Michel = f.read()
Michel = Michel[Michel_start_index:Michel_end_index]


filepath = '/content/Morality.txt'

with open(filepath) as f:
  Morality = f.read()
Morality = Morality[Morality_start_index:Morality_end_index]


filepath = '/content/Plato.txt'

with open(filepath) as f:
  Plato = f.read()
Plato = Plato[Plato_start_index:Plato_end_index]


filepath = '/content/Russell.txt'

with open(filepath) as f:
  Russell = f.read()
Russell = Russell[Russell_start_index:Russell_end_index]


filepath = '/content/Sage.txt'

with open(filepath) as f:
  Sage = f.read()
Sage = Sage[Sage_start_index:Sage_end_index]


filepath = '/content/Sartre.txt'

with open(filepath) as f:
  Sartre = f.read()
Sartre = Sartre[Satre_start_index:Satre_end_index]


filepath = '/content/Second.txt'

with open(filepath) as f:
  Second = f.read()
Second = Second[Second_start_index:Second_end_index]


filepath = '/content/Sisyphus.txt'

with open(filepath) as f:
  Sisyphus = f.read()
Sisyphus = Sisyphus[Sisyphus_start_index:Sisyphus_end_index]


filepath = '/content/Tao.txt'

with open(filepath) as f:
  Tao = f.read()
Tao = Tao[Tao_start_index:Tao_end_index]


filepath = '/content/Unapishads.txt'

with open(filepath) as f:
  Unapishads = f.read()
Unapishads = Unapishads[Unapishads_start_index:Unapishads_end_index]


filepath = '/content/Woolf.txt'

with open(filepath) as f:
  Woolf = f.read()
Woolf = Woolf[Woolf_start_index:Woolf_end_index]

African += "\n"
African += Analects
African += "\n"
African += Aquinas
African += "\n"
African += City
African += "\n"
African += Discourses
African += "\n"
African += Fire
African += "\n"
African += Gita
African += "\n"
African += Hegel
African += "\n"
African += Heidigger
African += "\n"
African += Investigations
African += "\n"
African += Kant
African += "\n"
African += Locke
African += "\n"
African += Ludwig
African += "\n"
African += Mary
African += "\n"
African += Meditations
African += "\n"
African += Michel
African += "\n"
African += Morality
African += "\n"
African += Plato
African += "\n"
African += Russell
African += "\n"
African += Sage
African += "\n"
African += Sartre
African += "\n"
African += Second
African += "\n"
African += Sisyphus
African += "\n"
African += Tao
African += "\n"
African += Unapishads
African += "\n"
African += Woolf

with open('philosophers.txt', 'w') as fp:
    fp.write(African)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-97ed62b399a8> in <module>()
#       1 filepath = '/content/African.txt'
#       2
# ----> 3 with open(filepath) as f:
#       4   African = f.read()
#       5 African = African[africa_start_index:africa_end_index]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/African.txt'

# %%
import string

filepath = '/content/philosophers.txt'

with open(filepath) as f:
  Phil = f.read()
Phil = Phil.replace("Get any book for free on: www.Abika.com", "")
Phil = Phil.replace("§", "")
Phil = Phil.replace("ON BEING AND ESSENCE", "")
Phil = Phil.replace("1", "")

translation_table = str.maketrans('', '', string.digits)

Phil = Phil.translate(translation_table)

with open('philRev.txt', 'w') as fp:
    fp.write(Phil)
