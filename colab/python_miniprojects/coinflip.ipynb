# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt


count = 0
times = 20000

for j in range(times):
  x = 0
  for i in range(100):
    ran = random.randint(0,2)
    if ran == 1:
      x+=1
    
  if x ==50:
    count +=1

print(count/times)
# Out:
# 0.07825
